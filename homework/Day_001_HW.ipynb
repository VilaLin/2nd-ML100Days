# %% [markdown]
# ## 作業1
#
# Data Scientist Job Market in the U.S.
# (https://www.kaggle.com/sl6149/data-scientist-job-market-in-the-us)
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# > 資料為 data science jobs <br/>
# > 可用來了解 data science 相關職務所需技能與分佈 <br/>
# > 也可以用來了解 data science 在美國個區域的發展狀況
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# > 資料從 Indeed website scrape 而來
#
# 3. 蒐集而來的資料型態為何
#
# > 非結構化: 文字, 以 CSV 儲存
#
# 4. 這組資料想解決的問題如何評估
#
# > AUC or MAP

# %% [markdown]
# ## 作業2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# > 提升業績 : 各司機平均單日載客數增加
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# > 需要資料:
#
# > * 上下班人員密集地區固定時間等車人數
# >    * 地區名稱
# >    * 時間
# >    * 人數
# > 收集方式:
# >> 各地區輪流拍照收集等車客人照片, 並依照等候人數轉化成數據, 持續收集1個月<br />
# >> 分批收集, 每批持續1週<br />
# >> * 第一批: 內湖科學園區,信義市府站
# >> * 第二批: 松江南京,南京復興站
# >> * 第三批: 圓山轉運站
# >> * 第四批: 台北火車站附近
#
# > 執行方式:
# >> 每30分鐘提示司機等車客人密集區位置<br />
# >> 請司機在靠近密集區附近等候
#
# 3. 蒐集而來的資料型態為何
#
# > 結構化: 數值
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# > DiffBefore = sum(司機單日載客量Before) / 司機人數<br/>
# > DiffAfter = sum(司機單日載客量After) / 司機人數<br/>
# > Diff = DiffAfter - DiffBefore<br/>
# >> * 須為正值<br/>
# >> * 越大表示效果越好<br/>

# %% [markdown]
# ## 作業3
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(x, y):
    """
    請完成這個 Function 後往下執行
    """
    return sum(pow((x - y), 2)) / len(x)

# %%
def mean_absolute_error(x, y):
    return sum(abs(x - y)) / len(x)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 216.029
# The Mean absolute error is 11.937
